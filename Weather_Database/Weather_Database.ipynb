# %%
# Import the dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities
cities = []
# Identify the nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count
len(cities)
# Out:
# 727

# %%
# Import the request library
import requests
# Import the API key
from config import weather_api_key
# Import the time library and the datetime module from the datetime library
import time
from datetime import datetime

# %%
# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data
city_data = []
# Print the beginning of the logging
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >=50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ", "+")

    # Log the URL, record, and set numbers and the city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        # Parse out the needed data
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                        "Lat": city_lat,
                        "Lng": city_lng,
                        "Max Temp": city_max_temp,
                        "Humidity": city_humidity,
                        "Cloudiness": city_clouds,
                        "Wind Speed": city_wind,
                        "Country": city_country,
                        "Current Description": city_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | poum
# Processing Record 2 of Set 1 | airai
# Processing Record 3 of Set 1 | barrow
# Processing Record 4 of Set 1 | faya
# Processing Record 5 of Set 1 | yanan
# City not found. Skipping...
# Processing Record 6 of Set 1 | rikitea
# Processing Record 7 of Set 1 | cherskiy
# Processing Record 8 of Set 1 | qaanaaq
# Processing Record 9 of Set 1 | butaritari
# Processing Record 10 of Set 1 | lagoa
# Processing Record 11 of Set 1 | collipulli
# Processing Record 12 of Set 1 | yanam
# Processing Record 13 of Set 1 | atuona
# Processing Record 14 of Set 1 | bluff
# Processing Record 15 of Set 1 | owase
# Processing Record 16 of Set 1 | cabo san lucas
# Processing Record 17 of Set 1 | busselton
# Processing Record 18 of Set 1 | kapaa
# Processing Record 19 of Set 1 | ushuaia
# Processing Record 20 of Set 1 | vaini
# Processing Record 21 of Set 1 | jamestown
# Processing Record 22 of Set 1 | vostok
# Processing Record 23 of Set 1 | sur
# Processing Record 24 of Set 1 | saint-pierre
# Processing Record 25 of Set 1 | presidencia roque saenz pena
# Processing Record 26 of Set 1 | luderitz
# Processing Record 27 of Set 1 | batticaloa
# Processing Record 28 of Set 1 | kavieng
# Processing Record 29 of Set 1 | teguldet
# Processing Record 30 of Set 1 | yellowknife
# Processing Record 31 of Set 1 | vardo
# Processing Record 32 of Set 1 | makakilo city
# Processing Record 33 of Set 1 | krasnokholm
# Processing Record 34 of Set 1 | tasiilaq
# Processing Record 35 of Set 1 | forest grove
# Processing Record 36 of Set 1 | bredasdorp
# Processing Record 37 of Set 1 | waingapu
# Processing Record 38 of Set 1 | seymchan
# Processing Record 39 of Set 1 | saint-raymond
# Processing Record 40 of Set 1 | missoula
# Processing Record 41 of Set 1 | nikolskoye
# Processing Record 42 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 43 of Set 1 | kracheh
# City not found. Skipping...
# Processing Record 44 of Set 1 | talnakh
# Processing Record 45 of Set 1 | uberaba
# Processing Record 46 of Set 1 | avarua
# Processing Record 47 of Set 1 | caravelas
# Processing Record 48 of Set 1 | opuwo
# Processing Record 49 of Set 1 | bambous virieux
# Processing Record 50 of Set 1 | wanning
# Processing Record 1 of Set 2 | hermanus
# Processing Record 2 of Set 2 | hanmer springs
# Processing Record 3 of Set 2 | punta arenas
# Processing Record 4 of Set 2 | cape town
# Processing Record 5 of Set 2 | cidreira
# Processing Record 6 of Set 2 | dikson
# Processing Record 7 of Set 2 | east london
# Processing Record 8 of Set 2 | nuuk
# Processing Record 9 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 10 of Set 2 | provideniya
# Processing Record 11 of Set 2 | fairbanks
# Processing Record 12 of Set 2 | adrar
# Processing Record 13 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 14 of Set 2 | mizdah
# Processing Record 15 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 16 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 17 of Set 2 | benoy
# Processing Record 18 of Set 2 | hambantota
# Processing Record 19 of Set 2 | vung tau
# Processing Record 20 of Set 2 | geraldton
# Processing Record 21 of Set 2 | puerto ayora
# Processing Record 22 of Set 2 | shimoda
# Processing Record 23 of Set 2 | saint george
# Processing Record 24 of Set 2 | qaqortoq
# Processing Record 25 of Set 2 | hofn
# Processing Record 26 of Set 2 | correntina
# Processing Record 27 of Set 2 | pevek
# Processing Record 28 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 29 of Set 2 | ostersund
# Processing Record 30 of Set 2 | guerrero negro
# Processing Record 31 of Set 2 | ponta do sol
# Processing Record 32 of Set 2 | susangerd
# Processing Record 33 of Set 2 | port elizabeth
# Processing Record 34 of Set 2 | esperance
# Processing Record 35 of Set 2 | vilyuysk
# Processing Record 36 of Set 2 | cascais
# Processing Record 37 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 38 of Set 2 | kodiak
# Processing Record 39 of Set 2 | taoudenni
# Processing Record 40 of Set 2 | basco
# Processing Record 41 of Set 2 | shchelyayur
# City not found. Skipping...
# Processing Record 42 of Set 2 | pisco
# Processing Record 43 of Set 2 | arraial do cabo
# Processing Record 44 of Set 2 | upata
# Processing Record 45 of Set 2 | nibbar
# Processing Record 46 of Set 2 | albany
# Processing Record 47 of Set 2 | castro
# Processing Record 48 of Set 2 | garissa
# Processing Record 49 of Set 2 | bethel
# Processing Record 50 of Set 2 | new norfolk
# Processing Record 1 of Set 3 | port alfred
# Processing Record 2 of Set 3 | saskylakh
# Processing Record 3 of Set 3 | mar del plata
# Processing Record 4 of Set 3 | darnah
# Processing Record 5 of Set 3 | chapada dos guimaraes
# Processing Record 6 of Set 3 | olafsvik
# Processing Record 7 of Set 3 | fort saint john
# City not found. Skipping...
# Processing Record 8 of Set 3 | gamba
# Processing Record 9 of Set 3 | san patricio
# Processing Record 10 of Set 3 | chokurdakh
# Processing Record 11 of Set 3 | gushikawa
# Processing Record 12 of Set 3 | mana
# Processing Record 13 of Set 3 | colares
# Processing Record 14 of Set 3 | altay
# Processing Record 15 of Set 3 | jiexiu
# Processing Record 16 of Set 3 | ilulissat
# Processing Record 17 of Set 3 | mataura
# Processing Record 18 of Set 3 | kemijarvi
# Processing Record 19 of Set 3 | ponta delgada
# Processing Record 20 of Set 3 | faanui
# Processing Record 21 of Set 3 | ribeira grande
# Processing Record 22 of Set 3 | aflu
# City not found. Skipping...
# Processing Record 23 of Set 3 | ayr
# Processing Record 24 of Set 3 | birao
# Processing Record 25 of Set 3 | sao joao da barra
# Processing Record 26 of Set 3 | bilma
# Processing Record 27 of Set 3 | fortuna
# Processing Record 28 of Set 3 | komsomolskiy
# Processing Record 29 of Set 3 | codrington
# Processing Record 30 of Set 3 | abha
# Processing Record 31 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 32 of Set 3 | superior
# Processing Record 33 of Set 3 | hilo
# Processing Record 34 of Set 3 | soyo
# Processing Record 35 of Set 3 | jizan
# Processing Record 36 of Set 3 | papasquiaro
# City not found. Skipping...
# Processing Record 37 of Set 3 | hobart
# Processing Record 38 of Set 3 | namibe
# Processing Record 39 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 40 of Set 3 | grindavik
# Processing Record 41 of Set 3 | padang
# Processing Record 42 of Set 3 | okha
# Processing Record 43 of Set 3 | port augusta
# Processing Record 44 of Set 3 | umea
# Processing Record 45 of Set 3 | ardabil
# Processing Record 46 of Set 3 | tuktoyaktuk
# Processing Record 47 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 48 of Set 3 | katsuura
# Processing Record 49 of Set 3 | tiksi
# Processing Record 50 of Set 3 | lilongwe
# Processing Record 1 of Set 4 | taitung
# Processing Record 2 of Set 4 | flinders
# Processing Record 3 of Set 4 | phan thiet
# Processing Record 4 of Set 4 | mahebourg
# Processing Record 5 of Set 4 | kaupanger
# Processing Record 6 of Set 4 | pangnirtung
# Processing Record 7 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 8 of Set 4 | porto novo
# Processing Record 9 of Set 4 | tucuman
# Processing Record 10 of Set 4 | victoria
# Processing Record 11 of Set 4 | kaitangata
# Processing Record 12 of Set 4 | gazli
# Processing Record 13 of Set 4 | vestmannaeyjar
# Processing Record 14 of Set 4 | ugoofaaru
# Processing Record 15 of Set 4 | sitka
# Processing Record 16 of Set 4 | maumere
# Processing Record 17 of Set 4 | molln
# Processing Record 18 of Set 4 | vallenar
# Processing Record 19 of Set 4 | diffa
# Processing Record 20 of Set 4 | garden city
# Processing Record 21 of Set 4 | cacapava do sul
# Processing Record 22 of Set 4 | hithadhoo
# Processing Record 23 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 24 of Set 4 | naryan-mar
# Processing Record 25 of Set 4 | chuy
# Processing Record 26 of Set 4 | manbij
# Processing Record 27 of Set 4 | lander
# Processing Record 28 of Set 4 | muroto
# Processing Record 29 of Set 4 | issia
# Processing Record 30 of Set 4 | portland
# Processing Record 31 of Set 4 | kudahuvadhoo
# Processing Record 32 of Set 4 | butka
# Processing Record 33 of Set 4 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 34 of Set 4 | laguna
# Processing Record 35 of Set 4 | rabo de peixe
# Processing Record 36 of Set 4 | imbituba
# Processing Record 37 of Set 4 | wajima
# Processing Record 38 of Set 4 | pangody
# Processing Record 39 of Set 4 | san vicente
# Processing Record 40 of Set 4 | nouadhibou
# Processing Record 41 of Set 4 | saint-philippe
# Processing Record 42 of Set 4 | high level
# Processing Record 43 of Set 4 | mailsi
# Processing Record 44 of Set 4 | safwah
# City not found. Skipping...
# Processing Record 45 of Set 4 | camacha
# Processing Record 46 of Set 4 | necochea
# Processing Record 47 of Set 4 | port macquarie
# Processing Record 48 of Set 4 | ust-tarka
# Processing Record 49 of Set 4 | carnarvon
# Processing Record 50 of Set 4 | shelburne
# Processing Record 1 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 2 of Set 5 | dobryatino
# Processing Record 3 of Set 5 | mount gambier
# Processing Record 4 of Set 5 | la ronge
# Processing Record 5 of Set 5 | yazman
# Processing Record 6 of Set 5 | jasper
# Processing Record 7 of Set 5 | hasaki
# Processing Record 8 of Set 5 | aguimes
# Processing Record 9 of Set 5 | teacapan
# Processing Record 10 of Set 5 | lodja
# Processing Record 11 of Set 5 | havre-saint-pierre
# Processing Record 12 of Set 5 | khatanga
# Processing Record 13 of Set 5 | puerto el triunfo
# Processing Record 14 of Set 5 | sorland
# Processing Record 15 of Set 5 | norman wells
# Processing Record 16 of Set 5 | vanimo
# Processing Record 17 of Set 5 | zeya
# Processing Record 18 of Set 5 | ketchikan
# Processing Record 19 of Set 5 | hualmay
# Processing Record 20 of Set 5 | santa cruz cabralia
# Processing Record 21 of Set 5 | mapastepec
# Processing Record 22 of Set 5 | constitucion
# Processing Record 23 of Set 5 | dubovka
# Processing Record 24 of Set 5 | deer lake
# Processing Record 25 of Set 5 | ryotsu
# Processing Record 26 of Set 5 | college
# Processing Record 27 of Set 5 | montepuez
# Processing Record 28 of Set 5 | lorengau
# Processing Record 29 of Set 5 | butte
# Processing Record 30 of Set 5 | acapulco
# Processing Record 31 of Set 5 | bonavista
# Processing Record 32 of Set 5 | thompson
# Processing Record 33 of Set 5 | gainesville
# Processing Record 34 of Set 5 | inhambane
# Processing Record 35 of Set 5 | kampene
# Processing Record 36 of Set 5 | pizarro
# Processing Record 37 of Set 5 | chicama
# Processing Record 38 of Set 5 | warri
# Processing Record 39 of Set 5 | farmington
# Processing Record 40 of Set 5 | valparaiso
# Processing Record 41 of Set 5 | nanortalik
# Processing Record 42 of Set 5 | san jose
# Processing Record 43 of Set 5 | simpang empat
# Processing Record 44 of Set 5 | bandarbeyla
# Processing Record 45 of Set 5 | tuatapere
# Processing Record 46 of Set 5 | betsiamites
# Processing Record 47 of Set 5 | mallapuram
# Processing Record 48 of Set 5 | kuala terengganu
# Processing Record 49 of Set 5 | victor harbor
# Processing Record 50 of Set 5 | harrisonville
# Processing Record 1 of Set 6 | aklavik
# Processing Record 2 of Set 6 | sistranda
# Processing Record 3 of Set 6 | georgetown
# Processing Record 4 of Set 6 | clyde river
# Processing Record 5 of Set 6 | rapid valley
# Processing Record 6 of Set 6 | nanakuli
# Processing Record 7 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 8 of Set 6 | morant bay
# Processing Record 9 of Set 6 | haines junction
# Processing Record 10 of Set 6 | saldanha
# Processing Record 11 of Set 6 | aizpute
# Processing Record 12 of Set 6 | sosnogorsk
# Processing Record 13 of Set 6 | katobu
# Processing Record 14 of Set 6 | santander jimenez
# Processing Record 15 of Set 6 | mayumba
# Processing Record 16 of Set 6 | sumbe
# Processing Record 17 of Set 6 | maneromango
# Processing Record 18 of Set 6 | dakoro
# Processing Record 19 of Set 6 | orange cove
# Processing Record 20 of Set 6 | xining
# Processing Record 21 of Set 6 | severo-kurilsk
# Processing Record 22 of Set 6 | vangaindrano
# Processing Record 23 of Set 6 | ostrovnoy
# Processing Record 24 of Set 6 | visby
# Processing Record 25 of Set 6 | byron bay
# Processing Record 26 of Set 6 | erenhot
# Processing Record 27 of Set 6 | wroclaw
# Processing Record 28 of Set 6 | tomatlan
# Processing Record 29 of Set 6 | yaan
# Processing Record 30 of Set 6 | villa constitucion
# Processing Record 31 of Set 6 | samalaeulu
# City not found. Skipping...
# Processing Record 32 of Set 6 | buqayq
# City not found. Skipping...
# Processing Record 33 of Set 6 | teya
# Processing Record 34 of Set 6 | naze
# Processing Record 35 of Set 6 | yarmouth
# Processing Record 36 of Set 6 | basyanovskiy
# City not found. Skipping...
# Processing Record 37 of Set 6 | boende
# Processing Record 38 of Set 6 | upernavik
# Processing Record 39 of Set 6 | srednekolymsk
# Processing Record 40 of Set 6 | udachnyy
# Processing Record 41 of Set 6 | trinidad
# Processing Record 42 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 43 of Set 6 | lebu
# Processing Record 44 of Set 6 | mezen
# Processing Record 45 of Set 6 | ahipara
# Processing Record 46 of Set 6 | bilibino
# Processing Record 47 of Set 6 | alakurtti
# Processing Record 48 of Set 6 | isangel
# Processing Record 49 of Set 6 | yibin
# Processing Record 50 of Set 6 | auki
# Processing Record 1 of Set 7 | gornopravdinsk
# Processing Record 2 of Set 7 | sao felix do xingu
# Processing Record 3 of Set 7 | nome
# Processing Record 4 of Set 7 | alofi
# Processing Record 5 of Set 7 | chauk
# Processing Record 6 of Set 7 | aksarka
# Processing Record 7 of Set 7 | kitgum
# Processing Record 8 of Set 7 | aporawan
# City not found. Skipping...
# Processing Record 9 of Set 7 | lebowakgomo
# Processing Record 10 of Set 7 | marzuq
# Processing Record 11 of Set 7 | savelugu
# Processing Record 12 of Set 7 | ust-tsilma
# Processing Record 13 of Set 7 | ruteng
# Processing Record 14 of Set 7 | creston
# Processing Record 15 of Set 7 | cortez
# Processing Record 16 of Set 7 | margate
# Processing Record 17 of Set 7 | manado
# Processing Record 18 of Set 7 | meulaboh
# Processing Record 19 of Set 7 | leningradskiy
# Processing Record 20 of Set 7 | raudeberg
# Processing Record 21 of Set 7 | antiguo morelos
# Processing Record 22 of Set 7 | bangaon
# Processing Record 23 of Set 7 | inuvik
# Processing Record 24 of Set 7 | prince rupert
# Processing Record 25 of Set 7 | hami
# Processing Record 26 of Set 7 | simao
# Processing Record 27 of Set 7 | matara
# Processing Record 28 of Set 7 | brigantine
# Processing Record 29 of Set 7 | abashiri
# Processing Record 30 of Set 7 | cayenne
# Processing Record 31 of Set 7 | yatou
# Processing Record 32 of Set 7 | sorvag
# City not found. Skipping...
# Processing Record 33 of Set 7 | lasa
# Processing Record 34 of Set 7 | grande prairie
# Processing Record 35 of Set 7 | gambiran
# Processing Record 36 of Set 7 | goure
# Processing Record 37 of Set 7 | vredendal
# Processing Record 38 of Set 7 | kastrakion
# Processing Record 39 of Set 7 | comodoro rivadavia
# Processing Record 40 of Set 7 | hay river
# Processing Record 41 of Set 7 | lipari
# Processing Record 42 of Set 7 | yayva
# Processing Record 43 of Set 7 | ishinomaki
# Processing Record 44 of Set 7 | cuenca
# Processing Record 45 of Set 7 | salalah
# Processing Record 46 of Set 7 | tahta
# Processing Record 47 of Set 7 | muros
# Processing Record 48 of Set 7 | sinnamary
# Processing Record 49 of Set 7 | mujiayingzi
# Processing Record 50 of Set 7 | nelson bay
# Processing Record 1 of Set 8 | huarmey
# Processing Record 2 of Set 8 | parabel
# Processing Record 3 of Set 8 | kontagora
# Processing Record 4 of Set 8 | jieshi
# Processing Record 5 of Set 8 | key west
# Processing Record 6 of Set 8 | alamosa
# Processing Record 7 of Set 8 | nizhniy baskunchak
# Processing Record 8 of Set 8 | goderich
# Processing Record 9 of Set 8 | novopokrovka
# Processing Record 10 of Set 8 | ambilobe
# Processing Record 11 of Set 8 | narsaq
# Processing Record 12 of Set 8 | crestview
# Processing Record 13 of Set 8 | jingdezhen
# Processing Record 14 of Set 8 | pathein
# Processing Record 15 of Set 8 | iskateley
# Processing Record 16 of Set 8 | thoen
# Processing Record 17 of Set 8 | a
# City not found. Skipping...
# Processing Record 18 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 19 of Set 8 | satitoa
# City not found. Skipping...
# Processing Record 20 of Set 8 | cairns
# Processing Record 21 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 22 of Set 8 | quatre cocos
# Processing Record 23 of Set 8 | rio grande
# Processing Record 24 of Set 8 | galbshtadt
# Processing Record 25 of Set 8 | bubaque
# Processing Record 26 of Set 8 | mandalgovi
# Processing Record 27 of Set 8 | kidal
# Processing Record 28 of Set 8 | julio de castilhos
# Processing Record 29 of Set 8 | half moon bay
# Processing Record 30 of Set 8 | sabzevar
# Processing Record 31 of Set 8 | betare oya
# Processing Record 32 of Set 8 | coahuayana
# Processing Record 33 of Set 8 | tunduru
# City not found. Skipping...
# Processing Record 34 of Set 8 | antofagasta
# Processing Record 35 of Set 8 | belluno
# Processing Record 36 of Set 8 | cap malheureux
# Processing Record 37 of Set 8 | dinsor
# City not found. Skipping...
# Processing Record 38 of Set 8 | north bend
# Processing Record 39 of Set 8 | bugiri
# Processing Record 40 of Set 8 | kushiro
# Processing Record 41 of Set 8 | tura
# Processing Record 42 of Set 8 | sampit
# Processing Record 43 of Set 8 | kruisfontein
# Processing Record 44 of Set 8 | cetraro
# Processing Record 45 of Set 8 | malangali
# Processing Record 46 of Set 8 | bardiyah
# Processing Record 47 of Set 8 | awjilah
# Processing Record 48 of Set 8 | villa rica
# Processing Record 49 of Set 8 | pital
# Processing Record 50 of Set 8 | agirish
# Processing Record 1 of Set 9 | hsichih
# City not found. Skipping...
# Processing Record 2 of Set 9 | taksimo
# Processing Record 3 of Set 9 | the valley
# Processing Record 4 of Set 9 | ngukurr
# City not found. Skipping...
# Processing Record 5 of Set 9 | jiddah
# City not found. Skipping...
# Processing Record 6 of Set 9 | russell
# Processing Record 7 of Set 9 | moose factory
# Processing Record 8 of Set 9 | ovre ardal
# Processing Record 9 of Set 9 | codajas
# Processing Record 10 of Set 9 | tlahualilo
# City not found. Skipping...
# Processing Record 11 of Set 9 | shibarghan
# City not found. Skipping...
# Processing Record 12 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 13 of Set 9 | balimo
# City not found. Skipping...
# Processing Record 14 of Set 9 | alihe
# Processing Record 15 of Set 9 | harper
# Processing Record 16 of Set 9 | arman
# Processing Record 17 of Set 9 | champerico
# Processing Record 18 of Set 9 | gombong
# Processing Record 19 of Set 9 | puerto escondido
# Processing Record 20 of Set 9 | sydney
# Processing Record 21 of Set 9 | santa maria
# Processing Record 22 of Set 9 | kavaratti
# Processing Record 23 of Set 9 | laizhou
# Processing Record 24 of Set 9 | turukhansk
# Processing Record 25 of Set 9 | sokoni
# Processing Record 26 of Set 9 | verkhoyansk
# Processing Record 27 of Set 9 | alice springs
# Processing Record 28 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 29 of Set 9 | burgersdorp
# Processing Record 30 of Set 9 | grand gaube
# Processing Record 31 of Set 9 | vernon
# Processing Record 32 of Set 9 | bud
# Processing Record 33 of Set 9 | rio de jesus
# Processing Record 34 of Set 9 | ballina
# Processing Record 35 of Set 9 | khajuraho
# Processing Record 36 of Set 9 | longyearbyen
# Processing Record 37 of Set 9 | sambava
# Processing Record 38 of Set 9 | goya
# Processing Record 39 of Set 9 | kargopol
# Processing Record 40 of Set 9 | uturoa
# Processing Record 41 of Set 9 | los llanos de aridane
# Processing Record 42 of Set 9 | bengkulu
# Processing Record 43 of Set 9 | iqaluit
# Processing Record 44 of Set 9 | shenkursk
# Processing Record 45 of Set 9 | bagotville
# Processing Record 46 of Set 9 | beringovskiy
# Processing Record 47 of Set 9 | krasnoselkup
# Processing Record 48 of Set 9 | andilamena
# Processing Record 49 of Set 9 | chapais
# Processing Record 50 of Set 9 | maniitsoq
# Processing Record 1 of Set 10 | pochutla
# Processing Record 2 of Set 10 | gravdal
# Processing Record 3 of Set 10 | khromtau
# Processing Record 4 of Set 10 | nioro
# Processing Record 5 of Set 10 | tanout
# Processing Record 6 of Set 10 | imeni babushkina
# Processing Record 7 of Set 10 | bosaso
# Processing Record 8 of Set 10 | tazagyukh
# City not found. Skipping...
# Processing Record 9 of Set 10 | susurluk
# Processing Record 10 of Set 10 | maceio
# Processing Record 11 of Set 10 | chifeng
# Processing Record 12 of Set 10 | te anau
# Processing Record 13 of Set 10 | santarem
# Processing Record 14 of Set 10 | mansoa
# Processing Record 15 of Set 10 | tsihombe
# City not found. Skipping...
# Processing Record 16 of Set 10 | oktyabrskiy
# Processing Record 17 of Set 10 | atar
# Processing Record 18 of Set 10 | uhlove
# Processing Record 19 of Set 10 | smithers
# Processing Record 20 of Set 10 | puerto narino
# Processing Record 21 of Set 10 | maribo
# Processing Record 22 of Set 10 | viligili
# City not found. Skipping...
# Processing Record 23 of Set 10 | kaiu
# Processing Record 24 of Set 10 | adelaide
# Processing Record 25 of Set 10 | sarny
# Processing Record 26 of Set 10 | kissidougou
# Processing Record 27 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 28 of Set 10 | redmond
# Processing Record 29 of Set 10 | torbay
# Processing Record 30 of Set 10 | praia da vitoria
# Processing Record 31 of Set 10 | galveston
# Processing Record 32 of Set 10 | lompoc
# Processing Record 33 of Set 10 | ambalavao
# Processing Record 34 of Set 10 | reconquista
# Processing Record 35 of Set 10 | bitung
# Processing Record 36 of Set 10 | acara
# Processing Record 37 of Set 10 | dingle
# Processing Record 38 of Set 10 | port lincoln
# Processing Record 39 of Set 10 | kahului
# Processing Record 40 of Set 10 | itigi
# Processing Record 41 of Set 10 | mahaicony
# City not found. Skipping...
# Processing Record 42 of Set 10 | cockburn town
# Processing Record 43 of Set 10 | souillac
# Processing Record 44 of Set 10 | kabompo
# Processing Record 45 of Set 10 | paita
# Processing Record 46 of Set 10 | kawana waters
# City not found. Skipping...
# Processing Record 47 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 48 of Set 10 | snasa
# Processing Record 49 of Set 10 | panama city
# Processing Record 50 of Set 10 | atagay
# Processing Record 1 of Set 11 | tra vinh
# Processing Record 2 of Set 11 | emba
# Processing Record 3 of Set 11 | pascagoula
# Processing Record 4 of Set 11 | skerries
# Processing Record 5 of Set 11 | westport
# Processing Record 6 of Set 11 | magway
# Processing Record 7 of Set 11 | boyolangu
# Processing Record 8 of Set 11 | bargal
# City not found. Skipping...
# Processing Record 9 of Set 11 | dudinka
# Processing Record 10 of Set 11 | dicabisagan
# Processing Record 11 of Set 11 | ancud
# Processing Record 12 of Set 11 | pacific grove
# Processing Record 13 of Set 11 | khor
# Processing Record 14 of Set 11 | arlit
# Processing Record 15 of Set 11 | coquimbo
# Processing Record 16 of Set 11 | sao miguel do araguaia
# Processing Record 17 of Set 11 | joshimath
# Processing Record 18 of Set 11 | manakara
# Processing Record 19 of Set 11 | sechura
# Processing Record 20 of Set 11 | nishihara
# Processing Record 21 of Set 11 | marawi
# Processing Record 22 of Set 11 | assiniboia
# Processing Record 23 of Set 11 | galich
# Processing Record 24 of Set 11 | gondanglegi
# Processing Record 25 of Set 11 | buchanan
# Processing Record 26 of Set 11 | grajewo
# Processing Record 27 of Set 11 | tessalit
# Processing Record 28 of Set 11 | singkawang
# Processing Record 29 of Set 11 | bambanglipuro
# Processing Record 30 of Set 11 | oktyabrskoye
# Processing Record 31 of Set 11 | kirakira
# Processing Record 32 of Set 11 | kjollefjord
# Processing Record 33 of Set 11 | hoi an
# Processing Record 34 of Set 11 | westpunt
# City not found. Skipping...
# Processing Record 35 of Set 11 | tazmalt
# Processing Record 36 of Set 11 | pervomaysk
# Processing Record 37 of Set 11 | skotterud
# Processing Record 38 of Set 11 | tautira
# Processing Record 39 of Set 11 | tazovskiy
# Processing Record 40 of Set 11 | walvis bay
# Processing Record 41 of Set 11 | eureka
# Processing Record 42 of Set 11 | ushtobe
# Processing Record 43 of Set 11 | kozluk
# Processing Record 44 of Set 11 | auxerre
# Processing Record 45 of Set 11 | kloulklubed
# Processing Record 46 of Set 11 | ola
# Processing Record 47 of Set 11 | bireun
# Processing Record 48 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 49 of Set 11 | datong
# Processing Record 50 of Set 11 | deming
# Processing Record 1 of Set 12 | kijang
# Processing Record 2 of Set 12 | asau
# Processing Record 3 of Set 12 | dali
# Processing Record 4 of Set 12 | orikum
# Processing Record 5 of Set 12 | yambio
# Processing Record 6 of Set 12 | kodinsk
# Processing Record 7 of Set 12 | vila franca do campo
# Processing Record 8 of Set 12 | merauke
# Processing Record 9 of Set 12 | benguela
# Processing Record 10 of Set 12 | ukiah
# Processing Record 11 of Set 12 | berlevag
# Processing Record 12 of Set 12 | jacareacanga
# Processing Record 13 of Set 12 | gerash
# Processing Record 14 of Set 12 | kaduy
# Processing Record 15 of Set 12 | egvekinot
# Processing Record 16 of Set 12 | edd
# Processing Record 17 of Set 12 | mecca
# Processing Record 18 of Set 12 | doka
# Processing Record 19 of Set 12 | hovd
# Processing Record 20 of Set 12 | biga
# Processing Record 21 of Set 12 | tulun
# Processing Record 22 of Set 12 | rio cuarto
# Processing Record 23 of Set 12 | yulara
# Processing Record 24 of Set 12 | tukrah
# Processing Record 25 of Set 12 | el tigre
# Processing Record 26 of Set 12 | kalevala
# Processing Record 27 of Set 12 | gafanha da encarnacao
# Processing Record 28 of Set 12 | ruwi
# Processing Record 29 of Set 12 | belomorsk
# Processing Record 30 of Set 12 | grabovo
# Processing Record 31 of Set 12 | lovington
# Processing Record 32 of Set 12 | kilimatinde
# Processing Record 33 of Set 12 | lahaina
# Processing Record 34 of Set 12 | zyryanovskiy
# City not found. Skipping...
# Processing Record 35 of Set 12 | ayagoz
# Processing Record 36 of Set 12 | hammerfest
# Processing Record 37 of Set 12 | ocos
# Processing Record 38 of Set 12 | hamilton
# Processing Record 39 of Set 12 | tual
# Processing Record 40 of Set 12 | nemuro
# Processing Record 41 of Set 12 | road town
# Processing Record 42 of Set 12 | atocha
# Processing Record 43 of Set 12 | phalia
# Processing Record 44 of Set 12 | charters towers
# Processing Record 45 of Set 12 | broome
# Processing Record 46 of Set 12 | ilembo
# Processing Record 47 of Set 12 | makat
# Processing Record 48 of Set 12 | kutum
# Processing Record 49 of Set 12 | coihaique
# Processing Record 50 of Set 12 | batagay
# Processing Record 1 of Set 13 | ngerengere
# Processing Record 2 of Set 13 | mgandu
# Processing Record 3 of Set 13 | salamanca
# Processing Record 4 of Set 13 | dunedin
# Processing Record 5 of Set 13 | palu
# Processing Record 6 of Set 13 | agadir
# Processing Record 7 of Set 13 | lata
# Processing Record 8 of Set 13 | abapo
# Processing Record 9 of Set 13 | vrangel
# Processing Record 10 of Set 13 | san cristobal
# Processing Record 11 of Set 13 | karamay
# City not found. Skipping...
# Processing Record 12 of Set 13 | fuyang
# Processing Record 13 of Set 13 | sucre
# Processing Record 14 of Set 13 | warrington
# Processing Record 15 of Set 13 | koryukivka
# Processing Record 16 of Set 13 | piacabucu
# Processing Record 17 of Set 13 | louisbourg
# City not found. Skipping...
# Processing Record 18 of Set 13 | qingdao
# Processing Record 19 of Set 13 | najran
# Processing Record 20 of Set 13 | lake city
# Processing Record 21 of Set 13 | ust-omchug
# Processing Record 22 of Set 13 | macaboboni
# City not found. Skipping...
# Processing Record 23 of Set 13 | lavrentiya
# Processing Record 24 of Set 13 | barawe
# City not found. Skipping...
# Processing Record 25 of Set 13 | markova
# Processing Record 26 of Set 13 | sola
# Processing Record 27 of Set 13 | danville
# Processing Record 28 of Set 13 | vila velha
# Processing Record 29 of Set 13 | ambunti
# Processing Record 30 of Set 13 | zvenyhorodka
# Processing Record 31 of Set 13 | san quintin
# Processing Record 32 of Set 13 | zhigansk
# Processing Record 33 of Set 13 | darhan
# Processing Record 34 of Set 13 | tokur
# Processing Record 35 of Set 13 | evensk
# Processing Record 36 of Set 13 | aksum
# Processing Record 37 of Set 13 | niono
# Processing Record 38 of Set 13 | mangrol
# Processing Record 39 of Set 13 | linxia
# Processing Record 40 of Set 13 | mangan
# Processing Record 41 of Set 13 | abnub
# Processing Record 42 of Set 13 | idenao
# Processing Record 43 of Set 13 | saint-leu
# Processing Record 44 of Set 13 | port-cartier
# Processing Record 45 of Set 13 | mehamn
# Processing Record 46 of Set 13 | masuri
# Processing Record 47 of Set 13 | samarai
# Processing Record 48 of Set 13 | scottsburgh
# City not found. Skipping...
# Processing Record 49 of Set 13 | qax
# Processing Record 50 of Set 13 | nhulunbuy
# Processing Record 1 of Set 14 | chibuto
# Processing Record 2 of Set 14 | yar-sale
# Processing Record 3 of Set 14 | vetlanda
# Processing Record 4 of Set 14 | tromso
# Processing Record 5 of Set 14 | misratah
# Processing Record 6 of Set 14 | olenino
# Processing Record 7 of Set 14 | yialos
# City not found. Skipping...
# Processing Record 8 of Set 14 | derzhavinsk
# Processing Record 9 of Set 14 | lukovetskiy
# Processing Record 10 of Set 14 | merrill
# Processing Record 11 of Set 14 | crepy-en-valois
# Processing Record 12 of Set 14 | klaksvik
# Processing Record 13 of Set 14 | kholm
# Processing Record 14 of Set 14 | chyhyryn
# Processing Record 15 of Set 14 | kvarkeno
# Processing Record 16 of Set 14 | jiangyou
# Processing Record 17 of Set 14 | ocampo
# Processing Record 18 of Set 14 | vrises
# Processing Record 19 of Set 14 | flin flon
# Processing Record 20 of Set 14 | burns lake
# Processing Record 21 of Set 14 | nabire
# Processing Record 22 of Set 14 | nanpara
# Processing Record 23 of Set 14 | tomari
# Processing Record 24 of Set 14 | lisakovsk
# Processing Record 25 of Set 14 | morondava
# Processing Record 26 of Set 14 | barra patuca
# Processing Record 27 of Set 14 | sao filipe
# Processing Record 28 of Set 14 | santa lucia
# Processing Record 29 of Set 14 | aloleng
# Processing Record 30 of Set 14 | taltal
# Processing Record 31 of Set 14 | kamaishi
# Processing Record 32 of Set 14 | oeiras
# Processing Record 33 of Set 14 | ixtapa
# Processing Record 34 of Set 14 | bajil
# Processing Record 35 of Set 14 | den helder
# Processing Record 36 of Set 14 | rock sound
# Processing Record 37 of Set 14 | kharan
# Processing Record 38 of Set 14 | kamenka
# Processing Record 39 of Set 14 | tilichiki
# Processing Record 40 of Set 14 | razole
# Processing Record 41 of Set 14 | villazon
# Processing Record 42 of Set 14 | podgorica
# Processing Record 43 of Set 14 | churapcha
# Processing Record 44 of Set 14 | loa janan
# Processing Record 45 of Set 14 | san ramon
# Processing Record 46 of Set 14 | oranjemund
# Processing Record 47 of Set 14 | tamale
# Processing Record 48 of Set 14 | eagle pass
# Processing Record 49 of Set 14 | sioux lookout
# Processing Record 50 of Set 14 | jiayuguan
# Processing Record 1 of Set 15 | puri
# Processing Record 2 of Set 15 | san andres
# Processing Record 3 of Set 15 | masty
# Processing Record 4 of Set 15 | rawson
# Processing Record 5 of Set 15 | giyani
# Processing Record 6 of Set 15 | chernyshevskiy
# Processing Record 7 of Set 15 | yerbogachen
# Processing Record 8 of Set 15 | polovinnoye
# Processing Record 9 of Set 15 | inirida
# Processing Record 10 of Set 15 | mitsamiouli
# Processing Record 11 of Set 15 | fort-shevchenko
# Processing Record 12 of Set 15 | chipinge
# Processing Record 13 of Set 15 | dukat
# Processing Record 14 of Set 15 | higuey
# City not found. Skipping...
# Processing Record 15 of Set 15 | fairview
# Processing Record 16 of Set 15 | calubcub
# City not found. Skipping...
# Processing Record 17 of Set 15 | jawa
# Processing Record 18 of Set 15 | saint-felicien
# Processing Record 19 of Set 15 | emirdag
# Processing Record 20 of Set 15 | synya
# Processing Record 21 of Set 15 | dzhusaly
# City not found. Skipping...
# Processing Record 22 of Set 15 | san jeronimo
# Processing Record 23 of Set 15 | iranshahr
# Processing Record 24 of Set 15 | pinotepa nacional
# Processing Record 25 of Set 15 | chitrakonda
# Processing Record 26 of Set 15 | araguacu
# Processing Record 27 of Set 15 | ponnani
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 666

# %%
# Convert the array of dictionaries to a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0        Poum -20.2333  164.0167     81.36        83         100       24.40
# 1       Airai  -8.9266  125.4092     76.82        49          61        3.65
# 2      Barrow  71.2906 -156.7887     -5.78        77         100       10.36
# 3        Faya  18.3851   42.4509     55.51        12           0        4.12
# 4     Rikitea -23.1203 -134.9692     78.57        66           1       11.92
# 5    Cherskiy  68.7500  161.3000     -2.15        86          56        3.09
# 6     Qaanaaq  77.4840  -69.3632     -1.89        92          95        7.52
# 7  Butaritari   3.0707  172.7902     81.63        77          63       17.40
# 8       Lagoa  39.0500  -27.9833     60.91        86         100       22.26
# 9  Collipulli -37.9500  -72.4333     53.62        85         100        3.62
#
#   Country Current Description
# 0      NC     overcast clouds
# 1      TL       broken clouds
# 2      US     overcast clouds
# 3      SA           clear sky
# 4      PF           clear sky
# 5      RU       broken clouds
# 6      GL     overcast clouds
# 7      KI          light rain
# 8      PT     overcast clouds
# 9      CL     overcast clouds

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]

city_data_df.head(10)
# Out:
#          City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Poum      NC -20.2333  164.0167     81.36        83         100
# 1       Airai      TL  -8.9266  125.4092     76.82        49          61
# 2      Barrow      US  71.2906 -156.7887     -5.78        77         100
# 3        Faya      SA  18.3851   42.4509     55.51        12           0
# 4     Rikitea      PF -23.1203 -134.9692     78.57        66           1
# 5    Cherskiy      RU  68.7500  161.3000     -2.15        86          56
# 6     Qaanaaq      GL  77.4840  -69.3632     -1.89        92          95
# 7  Butaritari      KI   3.0707  172.7902     81.63        77          63
# 8       Lagoa      PT  39.0500  -27.9833     60.91        86         100
# 9  Collipulli      CL -37.9500  -72.4333     53.62        85         100
#
#    Wind Speed Current Description
# 0       24.40     overcast clouds
# 1        3.65       broken clouds
# 2       10.36     overcast clouds
# 3        4.12           clear sky
# 4       11.92           clear sky
# 5        3.09       broken clouds
# 6        7.52     overcast clouds
# 7       17.40          light rain
# 8       22.26     overcast clouds
# 9        3.62     overcast clouds

# %%
# Create the output file (CSV)
output_data_file = "WeatherPy_Database.csv"
# Export the city_data into a csv
city_data_df.to_csv(output_data_file)
